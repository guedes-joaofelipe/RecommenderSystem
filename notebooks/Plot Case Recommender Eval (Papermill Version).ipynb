# %% [markdown]
# ## Imports

# %%
import os, sys, re, json, joblib
import ipywidgets as widgets
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np 
from IPython.display import clear_output    
lib_path = './../Sources'
if (lib_path not in sys.path):
    sys.path.append(lib_path) #src directory
from lpsrec.utils import create_gif    
from lpsrec.messaging.telegrambot import Bot

# %%
output_folder = './Output_Notebooks'
if not os.path.exists(output_folder):
    print ('Creating folder ' + output_folder)
    os.makedirs(output_folder)

# %% [markdown]
# ## Parameters
# Parameters to be used with Papermill

# %%
model_tag = 'MostPopular'
dataset_tag = 'ML100k'
evaluation_metrics = ['PREC', 'RECALL', 'NDCG', 'MRR', 'MAP']
rank_length = 30
nodes = 10
n_folds = 5
bot_alive = False

# %% [markdown]
# ## Plotting Results

# %%
style_dict = json.load(open('./style_dict.json', 'r'))
plt.rc('font', **style_dict['font'])
plt.rc('xtick', labelsize=style_dict['tick']['fontsize']) 
plt.rc('ytick', labelsize=style_dict['tick']['fontsize']) 
plt.rcParams.update({'figure.max_open_warning': 5})

# %%
dataset_output_folder = os.path.join('.', 'Outputs', dataset_tag)
bot = Bot(user_credentials='./JFGS.json')
bot.send_message(text="{}\nInitiating plot generation for the {} dataset on the {} model".format('-'*20, dataset_tag, model_tag)) if bot_alive else ''
# Out:
# ''

# %% [markdown]
# Grouping all folders eval metadata into a single file.
#
# The output should be a df_eval_metadata_fold{} containing all metrics and all sparsity cenarios

# %%
# %%time
for n_fold in np.arange(1, n_folds+1):
    for partition in np.arange(1, nodes+1, 1):
        analysis_tag = '_'.join([str(x) for x in [rank_length, nodes, partition]])
        variables_output_folder = os.path.join(dataset_output_folder, model_tag, 'Variables', analysis_tag)
        figures_output_folder = os.path.join(dataset_output_folder, model_tag, 'Figures', analysis_tag)
        df_eval_metadata_temp = pd.read_csv(os.path.join(variables_output_folder, 'df_eval_metadata_fold{}_{}.tsv'.format(n_folds, n_fold)), sep = '\t', header = 0)    
        df_eval_metadata = df_eval_metadata_temp.copy() if partition == 1 else df_eval_metadata.append(df_eval_metadata_temp)        
    df_eval_metadata.reset_index(drop = True, inplace = True)
    analysis_tag = '_'.join([str(x) for x in [rank_length, 'None']])
    variables_output_folder = os.path.join(dataset_output_folder, model_tag, 'Variables', analysis_tag)
    figures_output_folder = os.path.join(dataset_output_folder, model_tag, 'Figures', analysis_tag)
    if not os.path.exists(variables_output_folder):    
        os.makedirs(variables_output_folder)    
    if not os.path.exists(figures_output_folder):        
        os.makedirs(figures_output_folder)
    
    df_eval_metadata.to_csv(os.path.join(variables_output_folder, 'df_eval_metadata_fold{}.tsv'.format(n_fold)), sep = '\t', header = True, index = False)    
del df_eval_metadata_temp
del df_eval_metadata
# Out:
# Wall time: 2.24 s

# %% [markdown]
# Now that we have a df_eval_metadata_fold{}, we can create an arr_metrics for each metrics in each folder and append each arr_metric to an arr_metrics_folder.
#
# Example: for precision@k
#
#     arr_metric_folds = [arr_metric_fold1, arr_metric_fold2, ...]

# %%
dict_df_eval_metadata = dict()
for n_fold in np.arange(1, n_folds+1):
    filename = os.path.join(variables_output_folder, 'df_eval_metadata_fold{}.tsv'.format(n_fold))
    print (">> Getting file ", filename)
    df_eval_metadata = pd.read_csv(filename, sep = '\t', header = 0) 
    dict_df_eval_metadata[n_fold] = df_eval_metadata
# Out:
# >> Getting file  .\Outputs\ML100k\MostPopular\Variables\30_None\df_eval_metadata_fold1.tsv
# >> Getting file  .\Outputs\ML100k\MostPopular\Variables\30_None\df_eval_metadata_fold2.tsv
# >> Getting file  .\Outputs\ML100k\MostPopular\Variables\30_None\df_eval_metadata_fold3.tsv
# >> Getting file  .\Outputs\ML100k\MostPopular\Variables\30_None\df_eval_metadata_fold4.tsv
# >> Getting file  .\Outputs\ML100k\MostPopular\Variables\30_None\df_eval_metadata_fold5.tsv

# %%
# %%time
uss_limits = np.sort(np.array(df_eval_metadata['uss'].unique()))
iss_limits = np.sort(np.array(df_eval_metadata['iss'].unique()))
rank_lengths = np.arange(1, rank_length+1, 1) # Setting extra rank analysis
arr_metrics = np.repeat(None, n_folds)
  
for rank in rank_lengths: # [1, 2, 3, ..., rank_length]     
    dict_arr_metrics = dict()
    for m in evaluation_metrics:
        dict_arr_metrics[m] = np.repeat(None, n_folds)
    arr_rank_metrics = [m + '@' + str(rank) for m in evaluation_metrics]
    
    for column in arr_rank_metrics: # [PREC@1, RECALL@1, NDCG@1, ...]
        print ("\n> Processing ", column)
        arr_metric = np.zeros([len(uss_limits), len(iss_limits)])
        for n_fold in np.arange(1, n_folds+1):                        
            for uss_index, uss_limit in enumerate(uss_limits):
                for iss_index, iss_limit in enumerate(iss_limits):            
                    arr_metric[uss_index, iss_index] = dict_df_eval_metadata[n_fold][(dict_df_eval_metadata[n_fold]['uss'] == uss_limit) & (dict_df_eval_metadata[n_fold]['iss'] == iss_limit)][column].reset_index(drop = True)[0]
            # Colocar em cada metrica
            dict_arr_metrics[re.split("@", column)[0]][n_fold-1] = arr_metric
        filename = os.path.join(variables_output_folder, 'dict_arr_metrics_' + column.lower() + '_' + model_tag + '.joblib')
        print ("> Writing file ", filename)
        joblib.dump(dict_arr_metrics, filename)        
    
#     # Elapsed time analysis
#     arr_metric = np.zeros([len(uss_limits), len(iss_limits)])
#     for uss_index, uss_limit in enumerate(uss_limits):
#         for iss_index, iss_limit in enumerate(iss_limits):            
#             arr_metric[uss_index, iss_index] = df_eval_metadata[(df_eval_metadata['uss'] == uss_limit) & (df_eval_metadata['iss'] == iss_limit)]['elapsed_time'].reset_index(drop = True)[0]
#     joblib.dump(arr_metric, os.path.join(variables_output_folder, 'arr_elapsed_time_' + model_tag + '.joblib'))
# Out:
# > Processing  PREC@1
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_prec@1_MostPopular.joblib
#
# > Processing  RECALL@1
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_recall@1_MostPopular.joblib
#
# > Processing  NDCG@1
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_ndcg@1_MostPopular.joblib
#
# > Processing  MRR@1
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_mrr@1_MostPopular.joblib
#
# > Processing  MAP@1
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_map@1_MostPopular.joblib
#
# > Processing  PREC@2
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_prec@2_MostPopular.joblib
#
# > Processing  RECALL@2
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_recall@2_MostPopular.joblib
#
# > Processing  NDCG@2
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_ndcg@2_MostPopular.joblib
#
# > Processing  MRR@2
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_mrr@2_MostPopular.joblib
#
# > Processing  MAP@2
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_map@2_MostPopular.joblib
#
# > Processing  PREC@3
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_prec@3_MostPopular.joblib
#
# > Processing  RECALL@3
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_recall@3_MostPopular.joblib
#
# > Processing  NDCG@3
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_ndcg@3_MostPopular.joblib
#
# > Processing  MRR@3
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_mrr@3_MostPopular.joblib
#
# > Processing  MAP@3
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_map@3_MostPopular.joblib
#
# > Processing  PREC@4
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_prec@4_MostPopular.joblib
#
# > Processing  RECALL@4
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_recall@4_MostPopular.joblib
#
# > Processing  NDCG@4
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_ndcg@4_MostPopular.joblib
#
# > Processing  MRR@4
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_mrr@4_MostPopular.joblib
#
# > Processing  MAP@4
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_map@4_MostPopular.joblib
#
# > Processing  PREC@5
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_prec@5_MostPopular.joblib
#
# > Processing  RECALL@5
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_recall@5_MostPopular.joblib
#
# > Processing  NDCG@5
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_ndcg@5_MostPopular.joblib
#
# > Processing  MRR@5
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_mrr@5_MostPopular.joblib
#
# > Processing  MAP@5
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_map@5_MostPopular.joblib
#
# > Processing  PREC@6
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_prec@6_MostPopular.joblib
#
# > Processing  RECALL@6
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_recall@6_MostPopular.joblib
#
# > Processing  NDCG@6
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_ndcg@6_MostPopular.joblib
#
# > Processing  MRR@6
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_mrr@6_MostPopular.joblib
#
# > Processing  MAP@6
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_map@6_MostPopular.joblib
#
# > Processing  PREC@7
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_prec@7_MostPopular.joblib
#
# > Processing  RECALL@7
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_recall@7_MostPopular.joblib
#
# > Processing  NDCG@7
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_ndcg@7_MostPopular.joblib
#
# > Processing  MRR@7
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_mrr@7_MostPopular.joblib
#
# > Processing  MAP@7
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_map@7_MostPopular.joblib
#
# > Processing  PREC@8
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_prec@8_MostPopular.joblib
#
# > Processing  RECALL@8
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_recall@8_MostPopular.joblib
#
# > Processing  NDCG@8
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_ndcg@8_MostPopular.joblib
#
# > Processing  MRR@8
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_mrr@8_MostPopular.joblib
#
# > Processing  MAP@8
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_map@8_MostPopular.joblib
#
# > Processing  PREC@9
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_prec@9_MostPopular.joblib
#
# > Processing  RECALL@9
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_recall@9_MostPopular.joblib
#
# > Processing  NDCG@9
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_ndcg@9_MostPopular.joblib
#
# > Processing  MRR@9
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_mrr@9_MostPopular.joblib
#
# > Processing  MAP@9
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_map@9_MostPopular.joblib
#
# > Processing  PREC@10
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_prec@10_MostPopular.joblib
#
# > Processing  RECALL@10
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_recall@10_MostPopular.joblib
#
# > Processing  NDCG@10
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_ndcg@10_MostPopular.joblib
#
# > Processing  MRR@10
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_mrr@10_MostPopular.joblib
#
# > Processing  MAP@10
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_map@10_MostPopular.joblib
#
# > Processing  PREC@11
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_prec@11_MostPopular.joblib
#
# > Processing  RECALL@11
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_recall@11_MostPopular.joblib
#
# > Processing  NDCG@11
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_ndcg@11_MostPopular.joblib
#
# > Processing  MRR@11
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_mrr@11_MostPopular.joblib
#
# > Processing  MAP@11
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_map@11_MostPopular.joblib
#
# > Processing  PREC@12
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_prec@12_MostPopular.joblib
#
# > Processing  RECALL@12
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_recall@12_MostPopular.joblib
#
# > Processing  NDCG@12
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_ndcg@12_MostPopular.joblib
#
# > Processing  MRR@12
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_mrr@12_MostPopular.joblib
#
# > Processing  MAP@12
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_map@12_MostPopular.joblib
#
# > Processing  PREC@13
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_prec@13_MostPopular.joblib
#
# > Processing  RECALL@13
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_recall@13_MostPopular.joblib
#
# > Processing  NDCG@13
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_ndcg@13_MostPopular.joblib
#
# > Processing  MRR@13
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_mrr@13_MostPopular.joblib
#
# > Processing  MAP@13
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_map@13_MostPopular.joblib
#
# > Processing  PREC@14
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_prec@14_MostPopular.joblib
#
# > Processing  RECALL@14
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_recall@14_MostPopular.joblib
#
# > Processing  NDCG@14
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_ndcg@14_MostPopular.joblib
#
# > Processing  MRR@14
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_mrr@14_MostPopular.joblib
#
# > Processing  MAP@14
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_map@14_MostPopular.joblib
#
# > Processing  PREC@15
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_prec@15_MostPopular.joblib
#
# > Processing  RECALL@15
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_recall@15_MostPopular.joblib
#
# > Processing  NDCG@15
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_ndcg@15_MostPopular.joblib
#
# > Processing  MRR@15
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_mrr@15_MostPopular.joblib
#
# > Processing  MAP@15
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_map@15_MostPopular.joblib
#
# > Processing  PREC@16
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_prec@16_MostPopular.joblib
#
# > Processing  RECALL@16
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_recall@16_MostPopular.joblib
#
# > Processing  NDCG@16
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_ndcg@16_MostPopular.joblib
#
# > Processing  MRR@16
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_mrr@16_MostPopular.joblib
#
# > Processing  MAP@16
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_map@16_MostPopular.joblib
#
# > Processing  PREC@17
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_prec@17_MostPopular.joblib
#
# > Processing  RECALL@17
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_recall@17_MostPopular.joblib
#
# > Processing  NDCG@17
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_ndcg@17_MostPopular.joblib
#
# > Processing  MRR@17
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_mrr@17_MostPopular.joblib
#
# > Processing  MAP@17
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_map@17_MostPopular.joblib
#
# > Processing  PREC@18
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_prec@18_MostPopular.joblib
#
# > Processing  RECALL@18
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_recall@18_MostPopular.joblib
#
# > Processing  NDCG@18
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_ndcg@18_MostPopular.joblib
#
# > Processing  MRR@18
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_mrr@18_MostPopular.joblib
#
# > Processing  MAP@18
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_map@18_MostPopular.joblib
#
# > Processing  PREC@19
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_prec@19_MostPopular.joblib
#
# > Processing  RECALL@19
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_recall@19_MostPopular.joblib
#
# > Processing  NDCG@19
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_ndcg@19_MostPopular.joblib
#
# > Processing  MRR@19
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_mrr@19_MostPopular.joblib
#
# > Processing  MAP@19
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_map@19_MostPopular.joblib
#
# > Processing  PREC@20
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_prec@20_MostPopular.joblib
#
# > Processing  RECALL@20
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_recall@20_MostPopular.joblib
#
# > Processing  NDCG@20
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_ndcg@20_MostPopular.joblib
#
# > Processing  MRR@20
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_mrr@20_MostPopular.joblib
#
# > Processing  MAP@20
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_map@20_MostPopular.joblib
#
# > Processing  PREC@21
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_prec@21_MostPopular.joblib
#
# > Processing  RECALL@21
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_recall@21_MostPopular.joblib
#
# > Processing  NDCG@21
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_ndcg@21_MostPopular.joblib
#
# > Processing  MRR@21
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_mrr@21_MostPopular.joblib
#
# > Processing  MAP@21
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_map@21_MostPopular.joblib
#
# > Processing  PREC@22
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_prec@22_MostPopular.joblib
#
# > Processing  RECALL@22
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_recall@22_MostPopular.joblib
#
# > Processing  NDCG@22
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_ndcg@22_MostPopular.joblib
#
# > Processing  MRR@22
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_mrr@22_MostPopular.joblib
#
# > Processing  MAP@22
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_map@22_MostPopular.joblib
#
# > Processing  PREC@23
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_prec@23_MostPopular.joblib
#
# > Processing  RECALL@23
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_recall@23_MostPopular.joblib
#
# > Processing  NDCG@23
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_ndcg@23_MostPopular.joblib
#
# > Processing  MRR@23
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_mrr@23_MostPopular.joblib
#
# > Processing  MAP@23
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_map@23_MostPopular.joblib
#
# > Processing  PREC@24
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_prec@24_MostPopular.joblib
#
# > Processing  RECALL@24
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_recall@24_MostPopular.joblib
#
# > Processing  NDCG@24
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_ndcg@24_MostPopular.joblib
#
# > Processing  MRR@24
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_mrr@24_MostPopular.joblib
#
# > Processing  MAP@24
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_map@24_MostPopular.joblib
#
# > Processing  PREC@25
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_prec@25_MostPopular.joblib
#
# > Processing  RECALL@25
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_recall@25_MostPopular.joblib
#
# > Processing  NDCG@25
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_ndcg@25_MostPopular.joblib
#
# > Processing  MRR@25
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_mrr@25_MostPopular.joblib
#
# > Processing  MAP@25
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_map@25_MostPopular.joblib
#
# > Processing  PREC@26
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_prec@26_MostPopular.joblib
#
# > Processing  RECALL@26
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_recall@26_MostPopular.joblib
#
# > Processing  NDCG@26
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_ndcg@26_MostPopular.joblib
#
# > Processing  MRR@26
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_mrr@26_MostPopular.joblib
#
# > Processing  MAP@26
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_map@26_MostPopular.joblib
#
# > Processing  PREC@27
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_prec@27_MostPopular.joblib
#
# > Processing  RECALL@27
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_recall@27_MostPopular.joblib
#
# > Processing  NDCG@27
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_ndcg@27_MostPopular.joblib
#
# > Processing  MRR@27
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_mrr@27_MostPopular.joblib
#
# > Processing  MAP@27
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_map@27_MostPopular.joblib
#
# > Processing  PREC@28
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_prec@28_MostPopular.joblib
#
# > Processing  RECALL@28
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_recall@28_MostPopular.joblib
#
# > Processing  NDCG@28
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_ndcg@28_MostPopular.joblib
#
# > Processing  MRR@28
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_mrr@28_MostPopular.joblib
#
# > Processing  MAP@28
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_map@28_MostPopular.joblib
#
# > Processing  PREC@29
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_prec@29_MostPopular.joblib
#
# > Processing  RECALL@29
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_recall@29_MostPopular.joblib
#
# > Processing  NDCG@29
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_ndcg@29_MostPopular.joblib
#
# > Processing  MRR@29
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_mrr@29_MostPopular.joblib
#
# > Processing  MAP@29
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_map@29_MostPopular.joblib
#
# > Processing  PREC@30
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_prec@30_MostPopular.joblib
#
# > Processing  RECALL@30
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_recall@30_MostPopular.joblib
#
# > Processing  NDCG@30
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_ndcg@30_MostPopular.joblib
#
# > Processing  MRR@30
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_mrr@30_MostPopular.joblib
#
# > Processing  MAP@30
# > Writing file  .\Outputs\ML100k\MostPopular\Variables\30_None\dict_arr_metrics_map@30_MostPopular.joblib
# Wall time: 15min 20s

# %% [markdown]
# Plotting all metrics

# %%
def plot_metric(uss_limits, iss_limits, arr_metric, title, style_dict, contour=False, level_curve_step=100, filepath=None, clim=(0,1), stats='mean'):
    tick_step = 5
    fig, ax = plt.subplots(figsize=(style_dict['figure']['width'],style_dict['figure']['height']))   
    if contour:                
        cs_level = ax.contour(uss_limits, iss_limits, 
                          level_curve_step**(-1)*np.floor(level_curve_step*arr_metric), 
                          linewidths=(0.8,), colors='black', alpha=1,
                          levels=[x/100.0 for x in np.arange(0, 101, 10)])
        ax.clabel(cs_level, cs_level.levels, use_clabeltext=False, inline=True, 
                  fmt='%r', fontsize=style_dict['tick']['fontsize']-4, inline_spacing=3)
        cs = plt.contourf(uss_limits, iss_limits, arr_metric, cmap=style_dict['cmapping'],                   
                          levels=[x/100.0 for x in np.arange(0, 101, 2)])
        cs.changed()
        cbar = fig.colorbar(cs, ax=ax, ticks=[x/100.0 for x in np.arange(0, 101, 10)])
        ax.grid(color='k', linestyle='-', alpha=0.5)
    else:
        cax = plt.imshow(arr_metric, cmap=style_dict['cmapping'])
        plt.gca().invert_yaxis()
        if stats == 'mean':
            cbar = plt.colorbar(cax, ticks = [x/100.0 for x in np.arange(0,1000,10)], shrink = 0.83)
        else:
            cbar = plt.colorbar(cax, shrink = 0.83)
        ax.set_xticklabels(uss_limits[0:len(uss_limits):tick_step])
        ax.set_yticklabels(iss_limits[0:len(uss_limits):tick_step])
        ax.set_xticks(np.arange(0, len(uss_limits), tick_step))    
        ax.set_yticks(np.arange(0, len(iss_limits), tick_step))   
    
    ax.set_title(title.title(), fontsize = style_dict['label']['fontsize'])
    ax.set_xlabel('Last User Specific Sparsity', fontsize = style_dict['label']['fontsize'])
    ax.set_ylabel('Last Item Specific Sparsity', fontsize = style_dict['label']['fontsize'])    
    ax.tick_params(axis='both', which='major', labelsize=style_dict['tick']['fontsize'])
    cbar.ax.tick_params(labelsize = style_dict['tick']['fontsize'])    
    plt.clim(clim[0], clim[1])
    plt.xticks(rotation = 'horizontal')
    plt.close()
    
    if filepath is not None:        
        fig.savefig(filepath, bbox_inches = 'tight')
    return fig

# %%
# %%time
figs = {'mean': {}, 'std': {}}
for metric in evaluation_metrics:
    figs['mean'][metric+'@'] = list()
    figs['std'][metric+'@'] = list()

for rank in rank_lengths: #rank_lengths:#
    print ("Plotting rank ", rank)
    arr_rank_metrics = [m + '@' + str(rank) for m in evaluation_metrics]
    for column in arr_rank_metrics:
        dict_arr_metrics = joblib.load(os.path.join(variables_output_folder, 'dict_arr_metrics_' + column.lower() + '_' + model_tag + '.joblib'))        
        arr_metric = np.mean(dict_arr_metrics[re.split("@", column)[0]], axis=0)
        filepath = os.path.join(figures_output_folder, '2d-' + column + '_mean.png')        
        fig = plot_metric(uss_limits, iss_limits, arr_metric, dataset_tag + '-' + column, style_dict, contour=False, filepath=filepath)        
        figs['mean'][re.split("\d", column)[0]].append(fig) 
        
        if rank in [5,10,30]:
            filepath = os.path.join(figures_output_folder, '2d-' + column + '_mean_contour.png')        
            plot_metric(uss_limits, iss_limits, arr_metric, column, style_dict, contour=True, filepath=filepath)
            bot.send_message(filePath=filepath) if bot_alive else ''
        
        # Plotting standard deviation
        arr_metric = np.std(dict_arr_metrics[re.split("@", column)[0]], axis=0)
        filepath = os.path.join(figures_output_folder, '2d-' + column + '_std.png')   
        clim=(0,np.max(np.std(dict_arr_metrics[re.split("@", column)[0]], axis=0)))
        fig = plot_metric(uss_limits, iss_limits, arr_metric, column, style_dict, contour=False, filepath=filepath, clim=clim, stats='std')
        figs['std'][re.split("\d", column)[0]].append(fig)
# Out:
# Plotting rank  1
# Plotting rank  2
# Plotting rank  3
# Plotting rank  4
# Plotting rank  5
# Plotting rank  6
# Plotting rank  7
# Plotting rank  8
# Plotting rank  9
# Plotting rank  10
# Plotting rank  11
# Plotting rank  12
# Plotting rank  13
# Plotting rank  14
# Plotting rank  15
# Plotting rank  16
# Plotting rank  17
# Plotting rank  18
# Plotting rank  19
# Plotting rank  20
# Plotting rank  21
# Plotting rank  22
# Plotting rank  23
# Plotting rank  24
# Plotting rank  25
# Plotting rank  26
# Plotting rank  27
# Plotting rank  28
# Plotting rank  29
# Plotting rank  30
# Wall time: 1min 31s

# %%
# %%time
for metric in evaluation_metrics:    
    for stat in ['mean', 'std']:
        filepaths = [os.path.join(figures_output_folder, '2d-' + column + '_' + stat + '.png' ) for column in [metric + '@' + str(rank) for rank in rank_lengths]]
        output_filepath = os.path.join(figures_output_folder, '2d-' + metric + '@k_' + stat + '.gif' )
        create_gif(filepaths, output_filepath, duration=0.2)    
#         bot.send_message(filePath=output_filepath) if bot_alive else ''
# Out:
# Wall time: 8.78 s

# %%
show_metric = lambda metric, k, stat: figs[stat][metric + '@'][int(k)-1]
widgets.interact(show_metric, stat=['mean', 'std'], k=widgets.IntSlider(min=1, max=rank_length, step=1, value=10), figs=figs, metric=evaluation_metrics)
# Out:
# interactive(children=(Dropdown(description='metric', options=('PREC', 'RECALL', 'NDCG', 'MRR', 'MAP'), value='…
# <function __main__.<lambda>(metric, k, stat)>

# %% [markdown]
# ### Running Time

# %%
# df_eval_metadata.head()

# %%
# df_time_uss = df_eval_metadata[['uss', 'elapsed_time']].groupby(['uss']).mean().reset_index(drop = False)
# df_time_iss = df_eval_metadata[['iss', 'elapsed_time']].groupby(['iss']).mean().reset_index(drop = False)
# df_time_uss.head()

# %%
# fig, ax = plt.subplots(figsize=(style_dict['figure']['width'],style_dict['figure']['height']))    
# ax.plot(df_time_uss['uss'], df_time_uss['elapsed_time'], label='USS')
# ax.plot(df_time_iss['iss'], df_time_uss['elapsed_time'], label='ISS')
# ax.set_ylabel('Elapsed Time (s)', fontsize = style_dict['label']['fontsize'])
# ax.grid(True)
# ax.legend()
# filename = '2d-elapsed_time_mean_uss_iss.png'       
# fig.savefig(os.path.join(figures_output_folder, filename), bbox_inches = 'tight')

# %%
# arr_metric = joblib.load(os.path.join(variables_output_folder, 'arr_elapsed_time_' + model_tag + '.joblib'))        

# fig, ax = plt.subplots(figsize=(style_dict['figure']['width'],style_dict['figure']['height']))    
# cax = plt.imshow(arr_metric, cmap=cmapping)
# plt.gca().invert_yaxis()
# cbar = plt.colorbar(cax, shrink = 0.83)

# ax.annotate('Min: {:.02f}\nMax: {:.02f}'.format(np.min(arr_metric), np.max(arr_metric)), xy = (0, 0), fontsize=style_dict['label']['fontsize']-2, color='white')
# ax.set_xticklabels(uss_limits[0:len(uss_limits):tick_step])
# ax.set_yticklabels(iss_limits[0:len(uss_limits):tick_step])
# ax.set_xticks(np.arange(0, len(uss_limits), tick_step))    
# ax.set_yticks(np.arange(0, len(iss_limits), tick_step))    
# ax.set_xlabel('Last User Specific Sparsity', fontsize = style_dict['label']['fontsize'])
# ax.set_ylabel('Last Item Specific Sparsity', fontsize = style_dict['label']['fontsize'])    
# ax.tick_params(axis='both', which='major', labelsize=style_dict['tick']['fontsize'])
# cbar.set_label('Elapsed Time (s)', labelpad=-90,  y=1.08, rotation=0, fontsize = style_dict['label']['fontsize'])
# cbar.ax.tick_params(labelsize = style_dict['tick']['fontsize'])
# plt.xticks(rotation = 'vertical')
# plt.clim(np.floor(np.min(arr_metric)), np.ceil(np.max(arr_metric)))
# # ax.grid(c='k', ls='-', alpha=0.5)
# filename = '2d-elapsed_time.png'       
# fig.savefig(os.path.join(figures_output_folder, filename), bbox_inches = 'tight')
# figs[re.split("\d", column)[0]].append(fig) 
# if rank == rank_length: # Send only the target-analysis
#     bot.send_message(filePath=os.path.join(figures_output_folder, filename)) if bot_alive else ''
# #         clear_output()
# # plt.close()

# %% [markdown]
# __________________

# %%
# cmapping = "jet"
# tick_step = 5
# figs = dict()
# for metric in evaluation_metrics:
#     figs[metric+'@'] = list()

# for rank in rank_lengths:
#     arr_rank_metrics = [m + '@' + str(rank) for m in evaluation_metrics]
#     for column in arr_rank_metrics[:1]:
#         arr_metric = joblib.load(os.path.join(variables_output_folder, 'arr_' + column.lower() + '_' + model_tag + '.joblib'))        

#         fig, ax = plt.subplots(figsize=(style_dict['figure']['width'],style_dict['figure']['height']))    
#         cax = plt.imshow(arr_metric, cmap=cmapping)
#         plt.gca().invert_yaxis()
#         cbar = plt.colorbar(cax, ticks = [x/100.0 for x in np.arange(0,1000,10)], shrink = 0.83)

#         ax.set_xticklabels(uss_limits[0:len(uss_limits):tick_step])
#         ax.set_yticklabels(iss_limits[0:len(uss_limits):tick_step])
#         ax.set_xticks(np.arange(0, len(uss_limits), tick_step))    
#         ax.set_yticks(np.arange(0, len(iss_limits), tick_step))    
#         ax.set_xlabel('Last User Specific Sparsity', fontsize = style_dict['label']['fontsize'])
#         ax.set_ylabel('Last Item Specific Sparsity', fontsize = style_dict['label']['fontsize'])    
#         ax.tick_params(axis='both', which='major', labelsize=style_dict['tick']['fontsize'])
#         cbar.set_label(column.title(), labelpad=-50,  y=1.08, rotation=0, fontsize = style_dict['label']['fontsize'])
#         cbar.ax.tick_params(labelsize = style_dict['tick']['fontsize'])
#         plt.clim(0, 1)
#         plt.xticks(rotation = 'vertical')

#         filename = '2d-' + column + '.png'       
#         fig.savefig(os.path.join(figures_output_folder, filename), bbox_inches = 'tight')
#         figs[re.split("\d", column)[0]].append(fig) 
#         if rank == rank_length: # Send only the target-analysis
#             bot.send_message(filePath=os.path.join(figures_output_folder, filename)) if bot_alive else ''
# #         clear_output()
#         plt.close()

# %% [markdown]
# Old mean and std plots

# %%
# fig, ax = plt.subplots(figsize=(style_dict['figure']['width'],style_dict['figure']['height']))    
# cax = plt.imshow(arr_metric, cmap=cmapping)
# plt.gca().invert_yaxis()
# cbar = plt.colorbar(cax, ticks = [x/100.0 for x in np.arange(0,1000,10)], shrink = 0.83)

# ax.set_xticklabels(uss_limits[0:len(uss_limits):tick_step])
# ax.set_yticklabels(iss_limits[0:len(uss_limits):tick_step])
# ax.set_xticks(np.arange(0, len(uss_limits), tick_step))    
# ax.set_yticks(np.arange(0, len(iss_limits), tick_step))    
# ax.set_xlabel('Last User Specific Sparsity', fontsize = style_dict['label']['fontsize'])
# ax.set_ylabel('Last Item Specific Sparsity', fontsize = style_dict['label']['fontsize'])    
# ax.tick_params(axis='both', which='major', labelsize=style_dict['tick']['fontsize'])
# cbar.set_label(column.title(), labelpad=-50,  y=1.08, rotation=0, fontsize = style_dict['label']['fontsize'])
# cbar.ax.tick_params(labelsize = style_dict['tick']['fontsize'])
# plt.clim(0, 1)
# plt.xticks(rotation = 'vertical')

# %%
# cmapping = "jet"
# tick_step = 5
# for metric in evaluation_metrics:
#     figs['std'][metric+'@'] = list()
    
# for rank in rank_lengths[-1:-2:-1]:
#     arr_rank_metrics = [m + '@' + str(rank) for m in evaluation_metrics]
#     for column in arr_rank_metrics:
#         dict_arr_metrics = joblib.load(os.path.join(variables_output_folder, 'dict_arr_metrics_' + column.lower() + '_' + model_tag + '.joblib'))        
#         arr_metric = np.std(dict_arr_metrics[re.split("@", column)[0]], axis=0)

#         fig, ax = plt.subplots(figsize=(style_dict['figure']['width'],style_dict['figure']['height']))    
#         cax = plt.imshow(arr_metric, cmap=cmapping)
#         plt.gca().invert_yaxis()
#         cbar = plt.colorbar(cax, shrink = 0.83)

#         ax.set_xticklabels(uss_limits[0:len(uss_limits):tick_step])
#         ax.set_yticklabels(iss_limits[0:len(uss_limits):tick_step])
#         ax.set_xticks(np.arange(0, len(uss_limits), tick_step))    
#         ax.set_yticks(np.arange(0, len(iss_limits), tick_step))    
#         ax.set_xlabel('Last User Specific Sparsity', fontsize = style_dict['label']['fontsize'])
#         ax.set_ylabel('Last Item Specific Sparsity', fontsize = style_dict['label']['fontsize'])    
#         ax.tick_params(axis='both', which='major', labelsize=style_dict['tick']['fontsize'])
#         cbar.set_label(column.title(), labelpad=-50,  y=1.08, rotation=0, fontsize = style_dict['label']['fontsize'])
#         cbar.ax.tick_params(labelsize = style_dict['tick']['fontsize'])
#         plt.clim(0, np.max(np.std(dict_arr_metrics[re.split("@", column)[0]], axis=0)))
#         plt.xticks(rotation = 'vertical')

#         filename = '2d-' + column + '_std.png'       
#         fig.savefig(os.path.join(figures_output_folder, filename), bbox_inches = 'tight')
#         figs['std'][re.split("\d", column)[0]].append(fig) 
#         if rank == rank_length: # Send only the target-analysis
#             bot.send_message(filePath=os.path.join(figures_output_folder, filename)) if bot_alive else ''
#         plt.close()
